# %%
'''Comparison'''

import pandas as pd
import numpy as np
import sys, os, pathlib
import joblib 
import time 
from scipy.optimize import brentq
from scipy.stats import gaussian_kde

NOTEBOOK_DIR = pathlib.Path(os.getcwd())  
ROOT = NOTEBOOK_DIR.parents[0]  

sys.path.insert(0, str(ROOT))

from src.dataset_generator import sample_heston_lhs
from src.Heston_FFT import heston_price_fft
from src.Heston_MC import heston_mc_qe_price
from src.blacksholes import black_scholes

heston_nn = joblib.load("..\notebook\model_nn.pkl")


# FFT params
alpha  = 1.5
fft_N  = 4096     
eta    = 0.1      

# MC params
mc_steps = 150
mc_paths = 100_000
seed     = 42

# Random dataset (LHS)
test_df = sample_heston_lhs(100, seed=123, S0=105, q=0)
test_df = pd.DataFrame(test_df)


# Solver
def solver(df, alpha, eta, N, steps, path):

    S       = df['S0']
    K       = df['K']
    T       = df['T']
    r       = df['r']
    v0      = df['v0']
    kappa   = df['kappa']
    theta   = df['theta']
    sigma_v = df['sigma_v']
    rho     = df['rho']
    q       = df['q']

    # results
    fft_price, fft_time = [], []
    mc_price,  mc_time  = [], []
    nn_price,  nn_time  = [], []

    # loop 
    for i, row in df.iterrows():
        Si, Ki, Ti = float(row['S0']), float(row['K']), float(row['T'])
        ri, v0i    = float(row['r']), float(row['v0'])
        kappai, thetai = float(row['kappa']), float(row['theta'])
        sigi, rhoi = float(row['sigma_v']), float(row['rho'])
        qi = float(row['q'])

        # 1- FFT
        t0 = time.perf_counter()
        p_fft = heston_price_fft(
            S=Si, K=Ki, T=Ti, r=ri, v0=v0i,
            kappa=kappai, theta=thetai, sigma_v=sigi, rho=rhoi,
            option_type="call", q=qi, alpha=alpha, N=N, eta=eta
        )
        t1 = time.perf_counter()

        # 2- MC 
        t2 = time.perf_counter()
        p_mc = heston_mc_qe_price(
            Si, Ki, Ti, ri, qi,
            v0i, kappai, thetai, sigi, rhoi,
            steps=steps, paths=path,
            antithetic=True, seed=seed+i,
            option_type="call"
        )
        t3 = time.perf_counter()
        if isinstance(p_mc, tuple):
            p_mc = p_mc[0]


        # push risultati
        fft_price.append(float(p_fft))
        fft_time.append(t1 - t0)

        mc_price.append(float(p_mc))
        mc_time.append(t3 - t2)
    
    # 3- NN
    feats = ["m", "T", "r", "v0", "kappa", "theta", "sigma_v", "rho"]
    X = df[feats].to_numpy(dtype=float)
    t4 = time.perf_counter()
    p_nn = heston_nn.predict(X).astype(float).ravel()
    t5 = time.perf_counter()


    # cols
    df['FFT_price'] = fft_price
    df['FFT_time']  = fft_time

    df['MC_price']  = mc_price      
    df['MC_time']   = mc_time
    df['MC_error']  = abs(df['MC_price'] - df['FFT_price'])
    df['MC_error_rel']  = (df['MC_error']/np.maximum(np.abs(df['FFT_price']), 1e-6))
    df["MC_error_%"] = 100 * df["MC_error_rel"]

    df['NN_price'] = p_nn
    df['NN_time']  = (t5 - t4) / len(df) # already the mean
    df['NN_error']  = abs(df['NN_price'] - df['FFT_price'])
    df['NN_error_rel']  = (df['NN_error']/np.maximum(np.abs(df['FFT_price']), 1e-6))
    df["NN_error_%"] = 100 * df["NN_error_rel"]

    df.drop(columns=['MC_error_rel', 'NN_error_rel'], inplace=True)

    return df


#results_df = solver(test_df, alpha, eta, fft_N, mc_steps, mc_paths)
#results_df.to_csv('data/comparison_df.csv', index=False)

results_df = pd.read_csv("..\data\comparison_df.csv")

results_df
# Out:
#      S0           K         m         T         r  q        v0     kappa  \
# 0   105   98.793547  0.940891  1.022293  0.091720  0  0.042286  3.421521
# 1   105   80.677738  0.768359  0.883426  0.004107  0  0.016608  3.277008
# 2   105  142.992432  1.361833  0.666337  0.050121  0  0.086781  3.551251
# 3   105  126.158109  1.201506  1.188279 -0.001390  0  0.082694  4.534666
# 4   105   76.204570  0.725758  0.343483  0.045616  0  0.058265  0.788653
# ..  ...         ...       ...       ...       ... ..       ...       ...
# 95  105  110.519396  1.052566  0.730792  0.077420  0  0.040260  4.872894
# 96  105   91.092629  0.867549  0.380305  0.049462  0  0.064258  1.700969
# 97  105   68.951122  0.656677  0.897551  0.092073  0  0.037891  4.149947
# 98  105   71.190149  0.678001  1.254547  0.034675  0  0.027305  2.299072
# 99  105   90.031704  0.857445  0.122705  0.039955  0  0.039918  3.425733
#
#        theta   sigma_v  ...  FFT_price  FFT_time   MC_price   MC_time  \
# ...

# %%
# check

fft_try =  heston_price_fft(S=105, K=115.159, T=0.811, r=0.0921, v0=0.0765, kappa=4.841, theta=0.072, sigma_v=0.419, rho=-0.177,
                             option_type="call", q=0, alpha=alpha, N=fft_N, eta=eta)
MC_try =  heston_mc_qe_price(S0=105,  K=115.159, T=0.811, r=0.0921, q=0, v0=0.0765, kappa=4.841, theta=0.072, sigma_v=0.419, rho=-0.177,
                                         steps=mc_steps, paths=mc_paths,
                                         antithetic=True, seed=seed, option_type="call")
df_NN_try = pd.DataFrame([{"m": 1.0967,"T": 0.81,"r": 0.092,"v0": 0.076,"kappa": 4.841,"theta": 0.072,"sigma_v": 0.419,"rho": -0.177}])
NN_try = heston_nn.predict(df_NN_try)[0]

print(f"fft: {fft_try:.3f}")
print(f"mc: {MC_try[0]:.3f}")
print(f"nn: {NN_try:.3f}")
# Out:
# fft: 9.212
# mc: 9.292
# nn: 9.361

# %%
fft_avg_time = results_df['FFT_time'].mean()
mc_avg_time = results_df['MC_time'].mean()
nn_avg_time = results_df['NN_time'].mean()

fft_std_time = results_df['FFT_time'].std()
mc_std_time  = results_df['MC_time'].std()
nn_std_time  = results_df['NN_time'].std()

fft_total_time = results_df['FFT_time'].sum()
mc_total_time  = results_df['MC_time'].sum()
nn_total_time  = results_df['NN_time'].sum()

mc_avg_error = results_df['MC_error'].mean().round(7)
nn_avg_error = results_df['NN_error'].mean().round(7)

mc_avg_error_perc = results_df['MC_error_%'].mean().round(3)
nn_avg_error_perc = results_df['NN_error_%'].mean().round(3) # strongly influenced by outliers!

mc_med_error_perc = results_df['MC_error_%'].median().round(3)
nn_med_error_perc = results_df['NN_error_%'].median().round(3) 

mc_std_error = results_df['MC_error'].std().round(3)
nn_std_error = results_df['NN_error'].std().round(3)

mc_max_error_perc = results_df['MC_error_%'].max().round(3)
nn_max_error_perc = results_df['NN_error_%'].max().round(3)


summary = pd.DataFrame({
    "avg_time":   [fft_avg_time, mc_avg_time, nn_avg_time],
    "std_time":   [fft_std_time, mc_std_time, nn_std_time],
    "avg_error":  [0, mc_avg_error, nn_avg_error],   # FFT baseline = 0
    "avg_rel_error_(%)":  [0, mc_avg_error_perc, nn_avg_error_perc],
    "med_rel_error_(%)":  [0, mc_med_error_perc, nn_med_error_perc],
    "std_error":  [0, mc_std_error, nn_std_error],
    "max_rel_error_(%)":  [0, mc_max_error_perc, nn_max_error_perc]
}, index=["FFT", "MC", "NN"])

summary
# Out:
#      avg_time  std_time  avg_error  avg_rel_error_(%)  med_rel_error_(%)  \
# FFT  0.001675  0.000182   0.000000              0.000              0.000
# MC   0.608914  0.039866   0.033102              1.511              0.287
# NN   0.000091  0.000000   0.091888             26.391              0.968
#
#      std_error  max_rel_error_(%)
# FFT      0.000              0.000
# MC       0.044             66.018
# NN       0.092           1958.630

# %%
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# price distributions produced by the three methods
series = [
    ("FFT (Carr-Madan)", results_df["FFT_price"], "#2a78d6", dict(linewidth=3.5)),
    ("Monte Carlo (QE)", results_df["MC_price"],  "#1baf7a", dict(linewidth=2)),
    ("Neural network",   results_df["NN_price"],  "#eda100", dict(linewidth=2, linestyle=(0, (4, 3)))),
]

grid = np.linspace(0.0, max(s.max() for _, s, _, _ in series) * 1.05, 400)

fig, ax = plt.subplots(figsize=(9, 5))

for j, (label, vals, color, style) in enumerate(series):
    dens = gaussian_kde(vals)(grid)
    if j == 0:  # FFT = benchmark: light fill keeps it visible under the overlaps
        ax.fill_between(grid, dens, color=color, alpha=0.12, linewidth=0)
    ax.plot(grid, dens, color=color, label=label, **style)

ax.set_title("Price distributions produced by the three methods",
             loc="left", fontsize=12, color="#0b0b0b")
ax.set_xlabel("call price", color="#52514e")
ax.set_ylabel("density", color="#52514e")
ax.margins(x=0)
ax.set_ylim(bottom=0)
ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
ax.set_axisbelow(True)
for side in ("top", "right"):
    ax.spines[side].set_visible(False)
for side in ("left", "bottom"):
    ax.spines[side].set_color("#c3c2b7")
ax.tick_params(colors="#898781", labelsize=9)
ax.legend(frameon=False, loc="upper right", fontsize=10, labelcolor="#52514e")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relative Errors

# %%
C_FFT, C_MC, C_NN = "#2a78d6", "#1baf7a", "#eda100"

def style_ax(ax):
    ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
    ax.set_axisbelow(True)
    for side in ("top", "right"):
        ax.spines[side].set_visible(False)
    for side in ("left", "bottom"):
        ax.spines[side].set_color("#c3c2b7")
    ax.tick_params(colors="#898781", labelsize=9)

err_mc = results_df["MC_price"] - results_df["FFT_price"]
err_nn = results_df["NN_price"] - results_df["FFT_price"]

fig, axes = plt.subplots(1, 3, figsize=(16, 4.2))

# (1) signed error distributions: bias vs pure noise
lo = 1.15 * min(err_mc.min(), err_nn.min())
hi = 1.15 * max(err_mc.max(), err_nn.max())
grid_e = np.linspace(lo, hi, 400)
axes[0].axvline(0, color="#c3c2b7", linewidth=1, linestyle=(0, (3, 3)))
axes[0].plot(grid_e, gaussian_kde(err_mc)(grid_e), color=C_MC, linewidth=2, label="Monte Carlo (QE)")
axes[0].plot(grid_e, gaussian_kde(err_nn)(grid_e), color=C_NN, linewidth=2,
             linestyle=(0, (4, 3)), label="Neural network")
axes[0].set_title("Signed pricing error vs FFT", loc="left", fontsize=11, color="#0b0b0b")
axes[0].set_xlabel("price difference", color="#52514e")
axes[0].set_ylabel("density", color="#52514e")
axes[0].legend(frameon=False, fontsize=9, labelcolor="#52514e")

# (2)+(3) relative error vs moneyness and maturity
for ax, xcol, xlab in ((axes[1], "m", "moneyness K/S0"), (axes[2], "T", "maturity (years)")):
    ax.scatter(results_df[xcol], results_df["MC_error_%"], s=18, color=C_MC,
               alpha=0.75, linewidths=0, label="Monte Carlo (QE)")
    ax.scatter(results_df[xcol], results_df["NN_error_%"], s=18, color=C_NN,
               alpha=0.75, linewidths=0, label="Neural network")
    ax.set_yscale("log")
    ax.set_xlabel(xlab, color="#52514e")
    ax.set_title(f"|relative error| by {xlab.split()[0]}", loc="left", fontsize=11, color="#0b0b0b")
axes[1].set_ylabel("|relative error| vs FFT (%)", color="#52514e")

for ax in axes:
    style_ax(ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Implied-volatility smiles
#
# Prices from each method are converted to Black-Scholes IVs on a moneyness grid at three maturities. Errors that look negligible in price space get amplified here, especially where vega is small (short maturity, away from the money).
#
# Points where a price violates the no-arbitrage bounds (so no implied vol exists) are dropped. Note: this cell re-runs Monte Carlo on ~90 grid points, it takes about 1-2 minutes.

# %%
def implied_vol(price, S, K, T, r, q=0.0):
    intrinsic = max(S * np.exp(-q * T) - K * np.exp(-r * T), 0.0)
    if (not np.isfinite(price)) or price <= intrinsic + 1e-10 or price >= S * np.exp(-q * T):
        return np.nan
    try:
        return brentq(lambda s: black_scholes(S, K, T, r, s, "call", q) - price, 1e-4, 3.0)
    except ValueError:
        return np.nan

# representative Heston set (same as notebook 05; inside the NN training domain)
S0_, r_, q_ = 105.0, 0.09, 0.0
v0_, kappa_, theta_, sigmav_, rho_ = 0.075, 4.1, 0.06, 0.4, -0.3
maturities = [0.15, 0.50, 1.15]
m_grid = np.linspace(0.65, 1.35, 29)

fig, axes = plt.subplots(1, 3, figsize=(16, 4.2), sharey=True)
cnt = 0
for ax, T_ in zip(axes, maturities):
    K_grid = m_grid * S0_
    X_nn = pd.DataFrame({"m": m_grid, "T": T_, "r": r_, "v0": v0_, "kappa": kappa_,
                         "theta": theta_, "sigma_v": sigmav_, "rho": rho_})
    p_nn = heston_nn.predict(X_nn).astype(float).ravel()
    iv_fft, iv_mc, iv_nn = [], [], []
    for K_, pn in zip(K_grid, p_nn):
        pf = heston_price_fft(S0_, K_, T_, r_, v0_, kappa_, theta_, sigmav_, rho_,
                              q=q_, alpha=alpha, N=fft_N, eta=eta)
        pm, _ = heston_mc_qe_price(S0_, K_, T_, r_, q_, v0_, kappa_, theta_, sigmav_, rho_,
                                   steps=mc_steps, paths=mc_paths, antithetic=True, seed=seed + cnt)
        cnt += 1  # independent MC noise per grid point
        iv_fft.append(implied_vol(pf, S0_, K_, T_, r_))
        iv_mc.append(implied_vol(pm, S0_, K_, T_, r_))
        iv_nn.append(implied_vol(pn, S0_, K_, T_, r_))
    ax.plot(m_grid, iv_fft, color=C_FFT, linewidth=2.5, label="FFT (Carr-Madan)")
    ax.plot(m_grid, iv_mc, color=C_MC, linewidth=0, marker="o", markersize=4.5,
            label="Monte Carlo (QE)")
    ax.plot(m_grid, iv_nn, color=C_NN, linewidth=2, linestyle=(0, (4, 3)),
            label="Neural network")
    ax.set_title(f"T = {T_:.2f}y", loc="left", fontsize=11, color="#0b0b0b")
    ax.set_xlabel("moneyness K/S0", color="#52514e")
    style_ax(ax)
axes[0].set_ylabel("implied volatility", color="#52514e")
axes[-1].legend(frameon=False, fontsize=9, labelcolor="#52514e")
plt.tight_layout()
plt.show()
